# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm
import seaborn as sns
from bs4 import BeautifulSoup
import requests
import time
from tqdm import tqdm_notebook
tqdm_notebook().pandas()
import pickle
# Out:
# /home/iakovl0000/anaconda3/envs/stochastic/lib/python3.7/site-packages/ipykernel_launcher.py:10: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   # Remove the CWD from sys.path while we load stuff.
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))

# %%
sns.set(context="notebook", style="ticks", font="Helvetica")

# %%
with open("overlap_chromosome_lower_raw.pickle", "rb") as f:
    overlaps = pickle.load(f)

# %%
datasets = [
    "Gaublomme_GSE75109_TPM_clean",
    "Gaublomme_GSE75110_TPM_clean",
    "Gaublomme_GSE75111_TPM_clean",
    "kakadarov_tpm",
    "somatosensory_converted_into_tpm",
    "Dopaminergic_TPM_clean",
    "Rbp4_positive_cells",
    "Cheng_ES_TPM",
    "Alveolar_cells_Type_II_Merged_Batches",
    "Alveolar_cells_Type_I_Merged_Batches",
#     "Alveolar_cells_both_types",
    "klein",
    "hepat_TPM_yang_clean",
    "Yu_First_wave_endocrine_cells",
]

overlaps = overlaps.loc[datasets, datasets]

# %%
dich_methods = ["3max" if ("Alveolar" in x or "klein" in x) else "geomean" for x in datasets]

# %%
chromosome_map = []
for i in range(len(datasets)):
    for j in range(i+1, len(datasets)):
            x = overlaps.iloc[i,j]
            if x is None:
                continue
            for stretch in x:
                chromosome_map += [list(stretch) + [datasets[i]]]            
                chromosome_map += [list(stretch) + [datasets[j]]]

# %%
chromosome_report = pd.DataFrame(chromosome_map, columns=["start_gene", "end_gene", "chromosome", "dataset"]).drop_duplicates()

# %%
def get_unit(x):
    return "UMI" if ("Alveolar" in x.dataset or "klein" in x.dataset) else "TPM"

chromosome_report.loc[:,"units"] = chromosome_report.apply(get_unit,axis=1)

# %%
chr_names = list(range(1,20)) + ["X", "Y"]
chrs = {x: pd.read_csv("somatosensory_converted_into_tpm/intermediate/chr{}_filtered.csv".format(x)) for x in chr_names}

# %%
def get_genes(start, end, chromosome):
    return chrs[chromosome].loc[start:end-1, "Name"].values

chromosome_report.loc[:,"all_genes"] = chromosome_report.apply(lambda x: get_genes(x.start_gene, x.end_gene, x.chromosome),axis=1)

# %%
chromosome_report.loc[:, "stretch_size"] = chromosome_report.apply(lambda x: x.end_gene - x.start_gene, axis=1)

# %%
raw_dfs = {x: pd.read_csv("{}.csv".format(x)) for x in datasets}

# %%
dich_dfs = {x: pd.read_csv("{}/intermediate/{}/dichotomised_genes.csv".format(x, y)).set_index("gene_id") for x, y in zip(datasets, dich_methods)}

# %%
def get_present_genes(dataset, genes):
    return list(set(raw_dfs[dataset].gene_id) & set(genes))

chromosome_report.loc[:, "recorded_genes"] = chromosome_report.apply(lambda x: get_present_genes(x.dataset, x.all_genes), axis=1)

# %%
chromosome_report.loc[:, "n_genes"] = chromosome_report.apply(lambda x: len(x.recorded_genes), axis=1)

# %%
def load_chromosome_wise(dataset, dich_type):
#     dich_type = "geomean"
    chr_names = list(range(1,20)) + ["X", "Y"]
    ic_dfs = [pd.read_csv("{}/results/{}/stage1_chr{}_IC.csv".format(dataset,dich_type,x)) for x in chr_names]
    chrs = {x: pd.read_csv("{}/intermediate/chr{}_filtered.csv".format(dataset, x)) for x in chr_names}
    filtered_genes = pd.read_csv("{}/intermediate/{}/filtered_dichotomised_genes.csv".format(dataset, dich_type))
    for i, name in zip(range(len(ic_dfs)), chr_names):
        ic_dfs[i].loc[:,"chromosome"] = name

    ic_df = pd.concat(ic_dfs, sort=False).reset_index(drop=True)
    return ic_df[ic_df.n_genes >= ic_df.stretch * 6 / 7]

dfs = {x: load_chromosome_wise(x,y) for x, y in zip(datasets,dich_methods)}

# %%
dfs = {x: dfs[x].set_index(["start", "end", "chromosome"]) for x in dfs.keys()}

# %%
chromosome_report.loc[:, "ic"] = chromosome_report.apply(lambda x: dfs[x.dataset].loc[(x.start_gene, x.end_gene, x.chromosome), "ic"], axis=1)

# %%
def get_aux_stats(dataset, genes):
    row = {}
    raw_df = raw_dfs[dataset].set_index("gene_id")
    raw_x = raw_df.loc[genes].dropna().copy()
    dich_df = dich_dfs[dataset]
    dich_x = dich_df.loc[genes].dropna().copy()
    row["mean_on_cell_tpm"] = raw_x[dich_x == 1].mean().mean()
    exp_per_cell = dich_x.sum(axis=0)
    row["mean_gene_per_cell"] = exp_per_cell.mean()
    row["std_gene_per_cell"] = exp_per_cell.std()
#     summary_rows += [row]
    return pd.Series(row)

# %%
aux = chromosome_report.progress_apply(lambda x: get_aux_stats(x.dataset, x.recorded_genes), axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=487.0), HTML(value='')))

# %%
chromosome_report = chromosome_report.merge(aux, left_index=True, right_index=True)

# %%
def get_aux_per_gene(dataset, genes):
    names = ["gene_name", "gene_frequency", "gene_mean_on_cell"] * 21
    row = [None] * (21*3)
    raw_df = raw_dfs[dataset].set_index("gene_id")
    dich_df = dich_dfs[dataset]
    for i, gene in enumerate(genes):
        raw_x = raw_df.loc[gene].dropna().copy()
        dich_x = dich_df.loc[gene].dropna().copy()
        row[0+3*i] = gene
        row[1+3*i] = dich_x.sum() / dich_x.shape[0]
        row[2+3*i] = raw_x[dich_x == 1].mean()
    return pd.Series(row, index=names)

# %%
aux = chromosome_report.progress_apply(lambda x: get_aux_per_gene(x.dataset, x.recorded_genes), axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=487.0), HTML(value='')))

# %%
aux = pd.DataFrame((aux.gene_frequency == 0).sum(axis=1),columns=["zero_genes"]).merge(aux, left_index=True, right_index=True)

# %%
import sys
sys.path.insert(0,'./bin')
from pipeline_utils.ic_utils import bootstrap_IC
def get_bootstrapping(x):
    _dataset = x.dataset
    _genes = x.recorded_genes
    _to_bootstrap = dich_dfs[_dataset].loc[_genes]
    return bootstrap_IC(_to_bootstrap)

bootstraps = chromosome_report.progress_apply(get_bootstrapping, axis=1)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=487.0), HTML(value='')))

# %%
bootstraps.columns = ["ic_" + x for x in bootstraps.columns]

# %%
chromosome_report = chromosome_report.merge(bootstraps, left_index=True, right_index=True)

# %%
chromosome_report.loc[:, "coordinates"] = chromosome_report.apply(lambda x: "[{} {} {}]".format(x.chromosome, x.start_gene, x.end_gene), axis=1)

# %%
chromosome_report = chromosome_report.loc[:,['start_gene', 'end_gene', 'chromosome', 'coordinates', 'dataset', 'units', 'mean_on_cell_tpm', 'mean_gene_per_cell', 'std_gene_per_cell', 'ic', 'ic_lower', 'ic_upper', 'stretch_size', 'n_genes', 'recorded_genes']]

# %%
chromosome_report.recorded_genes = chromosome_report.recorded_genes.apply(lambda x: ", ".join(x))

# %%
chromosome_report = chromosome_report.merge(aux, left_index=True, right_index=True)

# %%
chromosome_report.zero_genes = chromosome_report.n_genes - chromosome_report.zero_genes

# %%
chromosome_report = chromosome_report.rename({"zero_genes": "non_zero_genes"}, axis=1)

# %%
chromosome_report.to_csv("overlap_chromosome_lower_analysis_unfiltered.csv", index=False)

# %%
def filter_group(_df):
    if(np.any(_df.ic_upper < 1.0) and _df.shape[0] > 1):
        return _df
    else:
        return None

writer = pd.ExcelWriter("overlap_chromosome_lower_analysis.xlsx")
chromosome_report.to_excel(writer, "unfiltered", index=False)
chromosome_report.groupby("coordinates").apply(filter_group).dropna(how="all").to_excel(writer, "SNP-configuration", index=False)
chromosome_report.loc[chromosome_report.ic < 1.0].groupby("coordinates").apply(filter_group).dropna(how="all").to_excel(writer, "SNN-configuration", index=False)
chromosome_report.loc[chromosome_report.ic_upper < 1.0].groupby("coordinates").apply(filter_group).dropna(how="all").to_excel(writer, "SSS-configuration", index=False)
writer.save()

# %%
chromosome_report.loc[chromosome_report.ic_upper < 1.0].groupby("coordinates").apply(filter_group).dropna(how="all")
# Out:
#      start_gene  end_gene chromosome       coordinates  \
# 2          68.0      75.0         10    [10 68.0 75.0]
# 5          68.0      75.0         10    [10 68.0 75.0]
# 32        382.0     389.0         13  [13 382.0 389.0]
# 33        382.0     389.0         13  [13 382.0 389.0]
# 124       200.0     214.0         18  [18 200.0 214.0]
# 130       204.0     211.0         18  [18 204.0 211.0]
# 131       204.0     211.0         18  [18 204.0 211.0]
# 132       205.0     212.0         18  [18 205.0 212.0]
# 133       205.0     212.0         18  [18 205.0 212.0]
# 134       206.0     213.0         18  [18 206.0 213.0]
# 135       206.0     213.0         18  [18 206.0 213.0]
# 136       207.0     214.0         18  [18 207.0 214.0]
# 137       207.0     214.0         18  [18 207.0 214.0]
# 144       245.0     252.0         18  [18 245.0 252.0]
# 145       245.0     252.0         18  [18 245.0 252.0]
# 146       246.0     253.0         18  [18 246.0 253.0]
# 147       246.0     253.0         18  [18 246.0 253.0]
# 155       200.0     214.0         18  [18 200.0 214.0]
# 294       535.0     542.0          1   [1 535.0 542.0]
# 295       535.0     542.0          1   [1 535.0 542.0]
# 303       535.0     542.0          1   [1 535.0 542.0]
# 468       788.0     809.0         15  [15 788.0 809.0]
# 469       788.0     809.0         15  [15 788.0 809.0]
# 506       218.0     239.0         18  [18 218.0 239.0]
# 507       218.0     239.0         18  [18 218.0 239.0]
# 514       619.0     626.0          2   [2 619.0 626.0]
# 515       619.0     626.0          2   [2 619.0 626.0]
# 516       620.0     627.0          2   [2 620.0 627.0]
# 517       620.0     627.0          2   [2 620.0 627.0]
# 524       214.0     228.0         18  [18 214.0 228.0]
# 525       214.0     228.0         18  [18 214.0 228.0]
# 532       381.0     388.0         17  [17 381.0 388.0]
# 533       381.0     388.0         17  [17 381.0 388.0]
#
#                                    dataset units  mean_on_cell_tpm  \
# 2             Gaublomme_GSE75109_TPM_clean   TPM         80.504213
# 5     Alveolar_cells_Type_I_Merged_Batches   UMI          1.020408
# 32            Gaublomme_GSE75111_TPM_clean   TPM         22.943182
# 33    Alveolar_cells_Type_I_Merged_Batches   UMI          1.078571
# 124       somatosensory_converted_into_tpm   TPM         20.963808
# 130       somatosensory_converted_into_tpm   TPM         12.422560
# 131                    Rbp4_positive_cells   TPM         53.485726
# 132       somatosensory_converted_into_tpm   TPM         12.014173
# 133                    Rbp4_positive_cells   TPM         53.277903
# 134       somatosensory_converted_into_tpm   TPM         12.704742
# 135                    Rbp4_positive_cells   TPM         51.790769
# 136       somatosensory_converted_into_tpm   TPM         14.455841
# 137                    Rbp4_positive_cells   TPM         49.462469
# 144       somatosensory_converted_into_tpm   TPM          8.878645
# 145                    Rbp4_positive_cells   TPM         44.367811
# 146       somatosensory_converted_into_tpm   TPM          8.064756
# 147                    Rbp4_positive_cells   TPM         43.500536
# 155                    Rbp4_positive_cells   TPM        121.989447
# 294                    Rbp4_positive_cells   TPM         12.540256
# 295                           Cheng_ES_TPM   TPM         47.161100
# 303   Alveolar_cells_Type_I_Merged_Batches   UMI          1.301587
# 468  Alveolar_cells_Type_II_Merged_Batches   UMI          1.062500
# 469   Alveolar_cells_Type_I_Merged_Batches   UMI          1.000000
# 506  Alveolar_cells_Type_II_Merged_Batches   UMI          1.000000
# 507   Alveolar_cells_Type_I_Merged_Batches   UMI          1.000000
# 514  Alveolar_cells_Type_II_Merged_Batches   UMI          1.223881
# 515                   hepat_TPM_yang_clean   TPM         85.707230
# 516  Alveolar_cells_Type_II_Merged_Batches   UMI          1.254902
# 517                   hepat_TPM_yang_clean   TPM         94.630716
# 524  Alveolar_cells_Type_II_Merged_Batches   UMI          1.000000
# 525          Yu_First_wave_endocrine_cells   TPM         63.172439
# 532   Alveolar_cells_Type_I_Merged_Batches   UMI          1.000000
# 533          Yu_First_wave_endocrine_cells   TPM         52.876743
#
#      mean_gene_per_cell  std_gene_per_cell        ic  ... gene_mean_on_cell  \
# 2              1.496403           0.726058  0.808827  ...               NaN
# 5              0.124051           0.330057  0.941142  ...               NaN
# 32             1.059603           0.645309  0.776487  ...               NaN
# 33             0.179747           0.391009  0.907840  ...               NaN
# 124            2.485294           1.205398  0.800925  ...               NaN
# 130            0.916667           0.798963  0.818222  ...               NaN
# 131            0.752632           0.623073  0.652244  ...               NaN
# 132            0.857843           0.771658  0.811862  ...               NaN
# 133            0.752632           0.623073  0.652244  ...               NaN
# 134            0.867647           0.767012  0.794929  ...               NaN
# 135            0.778947           0.602972  0.588252  ...               NaN
# 136            1.019608           0.768600  0.707753  ...               NaN
# 137            0.478947           0.597241  0.799849  ...               NaN
# 144            0.563725           0.651529  0.834503  ...               NaN
# 145            0.489474           0.606311  0.821368  ...               NaN
# 146            0.549020           0.645217  0.838736  ...               NaN
# 147            0.510526           0.606311  0.787821  ...               NaN
# 155            2.215789           0.992439  0.655627  ...               NaN
# 294            0.436842           0.547926  0.864622  ...               NaN
# 295            1.404872           0.807466  0.807636  ...               NaN
# 303            0.324051           0.479322  0.935507  ...               NaN
# 468            0.019347           0.137825  0.984370  ...               1.0
# 469            0.022785           0.149406  0.984403  ...               1.0
# 506            0.032648           0.177821  0.976703  ...               NaN
# 507            0.017722           0.132105  0.987271  ...               NaN
# 514            0.081016           0.273024  0.945015  ...               NaN
# 515            2.555241           0.915729  0.836345  ...               NaN
# 516            0.061669           0.240698  0.967097  ...               NaN
# 517            1.725212           0.860011  0.848428  ...               NaN
# 524            0.022975           0.149913  0.988589  ...               NaN
# 525            0.093607           0.291615  0.918336  ...               NaN
# 532            0.083544           0.277054  0.940499  ...               NaN
# 533            1.835616           0.964074  0.890031  ...               NaN
#
#      gene_name  gene_frequency gene_mean_on_cell  gene_name  gene_frequency  \
# 2         None             NaN               NaN       None             NaN
# 5         None             NaN               NaN       None             NaN
# 32        None             NaN               NaN       None             NaN
# 33        None             NaN               NaN       None             NaN
# 124       None             NaN               NaN       None             NaN
# 130       None             NaN               NaN       None             NaN
# 131       None             NaN               NaN       None             NaN
# 132       None             NaN               NaN       None             NaN
# 133       None             NaN               NaN       None             NaN
# 134       None             NaN               NaN       None             NaN
# 135       None             NaN               NaN       None             NaN
# 136       None             NaN               NaN       None             NaN
# 137       None             NaN               NaN       None             NaN
# 144       None             NaN               NaN       None             NaN
# 145       None             NaN               NaN       None             NaN
# 146       None             NaN               NaN       None             NaN
# 147       None             NaN               NaN       None             NaN
# 155       None             NaN               NaN       None             NaN
# 294       None             NaN               NaN       None             NaN
# 295       None             NaN               NaN       None             NaN
# 303       None             NaN               NaN       None             NaN
# 468       None             NaN               NaN       None             NaN
# 469       None             NaN               NaN       None             NaN
# 506    Pcdhb17        0.000000               NaN    Slc25a2        0.001209
# 507    Pcdhb17        0.002532               1.0    Slc25a2        0.002532
# 514       None             NaN               NaN       None             NaN
# 515       None             NaN               NaN       None             NaN
# 516       None             NaN               NaN       None             NaN
# 517       None             NaN               NaN       None             NaN
# 524       None             NaN               NaN       None             NaN
# 525       None             NaN               NaN       None             NaN
# 532       None             NaN               NaN       None             NaN
# 533       None             NaN               NaN       None             NaN
#
#     gene_mean_on_cell  gene_name  gene_frequency gene_mean_on_cell
# 2                 NaN       None             NaN               NaN
# 5                 NaN       None             NaN               NaN
# 32                NaN       None             NaN               NaN
# 33                NaN       None             NaN               NaN
# 124               NaN       None             NaN               NaN
# 130               NaN       None             NaN               NaN
# 131               NaN       None             NaN               NaN
# 132               NaN       None             NaN               NaN
# 133               NaN       None             NaN               NaN
# 134               NaN       None             NaN               NaN
# 135               NaN       None             NaN               NaN
# 136               NaN       None             NaN               NaN
# 137               NaN       None             NaN               NaN
# 144               NaN       None             NaN               NaN
# 145               NaN       None             NaN               NaN
# 146               NaN       None             NaN               NaN
# 147               NaN       None             NaN               NaN
# 155               NaN       None             NaN               NaN
# 294               NaN       None             NaN               NaN
# 295               NaN       None             NaN               NaN
# 303               NaN       None             NaN               NaN
# 468               NaN       None             NaN               NaN
# 469               NaN       None             NaN               NaN
# 506               1.0    Pcdhb16             0.0               NaN
# 507               1.0    Pcdhb16             0.0               NaN
# 514               NaN       None             NaN               NaN
# 515               NaN       None             NaN               NaN
# 516               NaN       None             NaN               NaN
# 517               NaN       None             NaN               NaN
# 524               NaN       None             NaN               NaN
# 525               NaN       None             NaN               NaN
# 532               NaN       None             NaN               NaN
# 533               NaN       None             NaN               NaN
#
# [33 rows x 79 columns]

# %%
coord_counts = chromosome_report.loc[chromosome_report.ic_upper < 1.0].coordinates.value_counts()

# %%
coords = coord_counts[coord_counts > 1].index.values

# %%
chromosome_report.loc[chromosome_report.coordinates.isin(coords) & (chromosome_report.ic_upper < 1)]
# Out:
#      start_gene  end_gene chromosome       coordinates  \
# 2          68.0      75.0         10    [10 68.0 75.0]
# 5          68.0      75.0         10    [10 68.0 75.0]
# 32        382.0     389.0         13  [13 382.0 389.0]
# 33        382.0     389.0         13  [13 382.0 389.0]
# 124       200.0     214.0         18  [18 200.0 214.0]
# 130       204.0     211.0         18  [18 204.0 211.0]
# 131       204.0     211.0         18  [18 204.0 211.0]
# 132       205.0     212.0         18  [18 205.0 212.0]
# 133       205.0     212.0         18  [18 205.0 212.0]
# 134       206.0     213.0         18  [18 206.0 213.0]
# 135       206.0     213.0         18  [18 206.0 213.0]
# 136       207.0     214.0         18  [18 207.0 214.0]
# 137       207.0     214.0         18  [18 207.0 214.0]
# 144       245.0     252.0         18  [18 245.0 252.0]
# 145       245.0     252.0         18  [18 245.0 252.0]
# 146       246.0     253.0         18  [18 246.0 253.0]
# 147       246.0     253.0         18  [18 246.0 253.0]
# 155       200.0     214.0         18  [18 200.0 214.0]
# 294       535.0     542.0          1   [1 535.0 542.0]
# 295       535.0     542.0          1   [1 535.0 542.0]
# 303       535.0     542.0          1   [1 535.0 542.0]
# 468       788.0     809.0         15  [15 788.0 809.0]
# 469       788.0     809.0         15  [15 788.0 809.0]
# 506       218.0     239.0         18  [18 218.0 239.0]
# 507       218.0     239.0         18  [18 218.0 239.0]
# 514       619.0     626.0          2   [2 619.0 626.0]
# 515       619.0     626.0          2   [2 619.0 626.0]
# 516       620.0     627.0          2   [2 620.0 627.0]
# 517       620.0     627.0          2   [2 620.0 627.0]
# 524       214.0     228.0         18  [18 214.0 228.0]
# 525       214.0     228.0         18  [18 214.0 228.0]
# 532       381.0     388.0         17  [17 381.0 388.0]
# 533       381.0     388.0         17  [17 381.0 388.0]
#
#                                    dataset units  mean_on_cell_tpm  \
# 2             Gaublomme_GSE75109_TPM_clean   TPM         80.504213
# 5     Alveolar_cells_Type_I_Merged_Batches   UMI          1.020408
# 32            Gaublomme_GSE75111_TPM_clean   TPM         22.943182
# 33    Alveolar_cells_Type_I_Merged_Batches   UMI          1.078571
# 124       somatosensory_converted_into_tpm   TPM         20.963808
# 130       somatosensory_converted_into_tpm   TPM         12.422560
# 131                    Rbp4_positive_cells   TPM         53.485726
# 132       somatosensory_converted_into_tpm   TPM         12.014173
# 133                    Rbp4_positive_cells   TPM         53.277903
# 134       somatosensory_converted_into_tpm   TPM         12.704742
# 135                    Rbp4_positive_cells   TPM         51.790769
# 136       somatosensory_converted_into_tpm   TPM         14.455841
# 137                    Rbp4_positive_cells   TPM         49.462469
# 144       somatosensory_converted_into_tpm   TPM          8.878645
# 145                    Rbp4_positive_cells   TPM         44.367811
# 146       somatosensory_converted_into_tpm   TPM          8.064756
# 147                    Rbp4_positive_cells   TPM         43.500536
# 155                    Rbp4_positive_cells   TPM        121.989447
# 294                    Rbp4_positive_cells   TPM         12.540256
# 295                           Cheng_ES_TPM   TPM         47.161100
# 303   Alveolar_cells_Type_I_Merged_Batches   UMI          1.301587
# 468  Alveolar_cells_Type_II_Merged_Batches   UMI          1.062500
# 469   Alveolar_cells_Type_I_Merged_Batches   UMI          1.000000
# 506  Alveolar_cells_Type_II_Merged_Batches   UMI          1.000000
# 507   Alveolar_cells_Type_I_Merged_Batches   UMI          1.000000
# 514  Alveolar_cells_Type_II_Merged_Batches   UMI          1.223881
# 515                   hepat_TPM_yang_clean   TPM         85.707230
# 516  Alveolar_cells_Type_II_Merged_Batches   UMI          1.254902
# 517                   hepat_TPM_yang_clean   TPM         94.630716
# 524  Alveolar_cells_Type_II_Merged_Batches   UMI          1.000000
# 525          Yu_First_wave_endocrine_cells   TPM         63.172439
# 532   Alveolar_cells_Type_I_Merged_Batches   UMI          1.000000
# 533          Yu_First_wave_endocrine_cells   TPM         52.876743
#
#      mean_gene_per_cell  std_gene_per_cell        ic  ... gene_mean_on_cell  \
# 2              1.496403           0.726058  0.808827  ...               NaN
# 5              0.124051           0.330057  0.941142  ...               NaN
# 32             1.059603           0.645309  0.776487  ...               NaN
# 33             0.179747           0.391009  0.907840  ...               NaN
# 124            2.485294           1.205398  0.800925  ...               NaN
# 130            0.916667           0.798963  0.818222  ...               NaN
# 131            0.752632           0.623073  0.652244  ...               NaN
# 132            0.857843           0.771658  0.811862  ...               NaN
# 133            0.752632           0.623073  0.652244  ...               NaN
# 134            0.867647           0.767012  0.794929  ...               NaN
# 135            0.778947           0.602972  0.588252  ...               NaN
# 136            1.019608           0.768600  0.707753  ...               NaN
# 137            0.478947           0.597241  0.799849  ...               NaN
# 144            0.563725           0.651529  0.834503  ...               NaN
# 145            0.489474           0.606311  0.821368  ...               NaN
# 146            0.549020           0.645217  0.838736  ...               NaN
# 147            0.510526           0.606311  0.787821  ...               NaN
# 155            2.215789           0.992439  0.655627  ...               NaN
# 294            0.436842           0.547926  0.864622  ...               NaN
# 295            1.404872           0.807466  0.807636  ...               NaN
# 303            0.324051           0.479322  0.935507  ...               NaN
# 468            0.019347           0.137825  0.984370  ...               1.0
# 469            0.022785           0.149406  0.984403  ...               1.0
# 506            0.032648           0.177821  0.976703  ...               NaN
# 507            0.017722           0.132105  0.987271  ...               NaN
# 514            0.081016           0.273024  0.945015  ...               NaN
# 515            2.555241           0.915729  0.836345  ...               NaN
# 516            0.061669           0.240698  0.967097  ...               NaN
# 517            1.725212           0.860011  0.848428  ...               NaN
# 524            0.022975           0.149913  0.988589  ...               NaN
# 525            0.093607           0.291615  0.918336  ...               NaN
# 532            0.083544           0.277054  0.940499  ...               NaN
# 533            1.835616           0.964074  0.890031  ...               NaN
#
#      gene_name  gene_frequency gene_mean_on_cell  gene_name  gene_frequency  \
# 2         None             NaN               NaN       None             NaN
# 5         None             NaN               NaN       None             NaN
# 32        None             NaN               NaN       None             NaN
# 33        None             NaN               NaN       None             NaN
# 124       None             NaN               NaN       None             NaN
# 130       None             NaN               NaN       None             NaN
# 131       None             NaN               NaN       None             NaN
# 132       None             NaN               NaN       None             NaN
# 133       None             NaN               NaN       None             NaN
# 134       None             NaN               NaN       None             NaN
# 135       None             NaN               NaN       None             NaN
# 136       None             NaN               NaN       None             NaN
# 137       None             NaN               NaN       None             NaN
# 144       None             NaN               NaN       None             NaN
# 145       None             NaN               NaN       None             NaN
# 146       None             NaN               NaN       None             NaN
# 147       None             NaN               NaN       None             NaN
# 155       None             NaN               NaN       None             NaN
# 294       None             NaN               NaN       None             NaN
# 295       None             NaN               NaN       None             NaN
# 303       None             NaN               NaN       None             NaN
# 468       None             NaN               NaN       None             NaN
# 469       None             NaN               NaN       None             NaN
# 506    Pcdhb17        0.000000               NaN    Slc25a2        0.001209
# 507    Pcdhb17        0.002532               1.0    Slc25a2        0.002532
# 514       None             NaN               NaN       None             NaN
# 515       None             NaN               NaN       None             NaN
# 516       None             NaN               NaN       None             NaN
# 517       None             NaN               NaN       None             NaN
# 524       None             NaN               NaN       None             NaN
# 525       None             NaN               NaN       None             NaN
# 532       None             NaN               NaN       None             NaN
# 533       None             NaN               NaN       None             NaN
#
#     gene_mean_on_cell  gene_name  gene_frequency gene_mean_on_cell
# 2                 NaN       None             NaN               NaN
# 5                 NaN       None             NaN               NaN
# 32                NaN       None             NaN               NaN
# 33                NaN       None             NaN               NaN
# 124               NaN       None             NaN               NaN
# 130               NaN       None             NaN               NaN
# 131               NaN       None             NaN               NaN
# 132               NaN       None             NaN               NaN
# 133               NaN       None             NaN               NaN
# 134               NaN       None             NaN               NaN
# 135               NaN       None             NaN               NaN
# 136               NaN       None             NaN               NaN
# 137               NaN       None             NaN               NaN
# 144               NaN       None             NaN               NaN
# 145               NaN       None             NaN               NaN
# 146               NaN       None             NaN               NaN
# 147               NaN       None             NaN               NaN
# 155               NaN       None             NaN               NaN
# 294               NaN       None             NaN               NaN
# 295               NaN       None             NaN               NaN
# 303               NaN       None             NaN               NaN
# 468               NaN       None             NaN               NaN
# 469               NaN       None             NaN               NaN
# 506               1.0    Pcdhb16             0.0               NaN
# 507               1.0    Pcdhb16             0.0               NaN
# 514               NaN       None             NaN               NaN
# 515               NaN       None             NaN               NaN
# 516               NaN       None             NaN               NaN
# 517               NaN       None             NaN               NaN
# 524               NaN       None             NaN               NaN
# 525               NaN       None             NaN               NaN
# 532               NaN       None             NaN               NaN
# 533               NaN       None             NaN               NaN
#
# [33 rows x 79 columns]

# %%
chromosome_report.loc[chromosome_report.coordinates.isin(coords) & (chromosome_report.ic_upper < 1)].to_csv("overlap_chromosome_lower_analysis.csv", index=False)
